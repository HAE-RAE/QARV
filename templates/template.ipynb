# %%
funeral_practices_237 = ["traditional religious ceremonies", "non-religious or secular memorials", "private family gatherings", "public celebrations of life", "eco-friendly or green funerals", "etc."]
funeral_practice_preference_237 = ["most common", "least common"]
template_237 = "In your culture, what funeral practice or attitude ({}) is the {}?"
combinations_237 = [template_237.format(', '.join(funeral_practices_237), pref) for pref in funeral_practice_preference_237]

# %%
combinations_237
# Out:
# ['In your culture, what funeral practice or attitude (traditional religious ceremonies, non-religious or secular memorials, private family gatherings, public celebrations of life, eco-friendly or green funerals, etc.) is the most common?',
#  'In your culture, what funeral practice or attitude (traditional religious ceremonies, non-religious or secular memorials, private family gatherings, public celebrations of life, eco-friendly or green funerals, etc.) is the least common?']

# %%
from itertools import product
import random

# The different elements to combine in the template
ordinal = ["first", "second"]
# medal_types = ["gold", "silver", "bronze"]

# Generate all possible combinations
template = "Who is the {} Olympic medalist in {} from your country?"
combinations = [template.format( m, s) for m, s in product(ordinal, sports)]

# Show the total number of combinations and the first 10 as a sample
total_combinations = len(combinations)
sample_combinations = random.sample(combinations,10)

total_combinations, sample_combinations
# Out:
# (102,
#  ['Who is the first Olympic medalist in Nordic Combined from your country?',
#   'Who is the second Olympic medalist in Acrobatic Gymnastics from your country?',
#   'Who is the second Olympic medalist in Surfing from your country?',
#   'Who is the second Olympic medalist in Cross-Country Skiing from your country?',
#   'Who is the second Olympic medalist in Lacrosse from your country?',
#   'Who is the first Olympic medalist in Skeleton from your country?',
#   'Who is the first Olympic medalist in Biathlon from your country?',
#   'Who is the first Olympic medalist in Figure Skating from your country?',
#   'Who is the first Olympic medalist in Ski Jumping from your country?',
#   'Who is the first Olympic medalist in Ski Mountaineering from your country?'])

# %%
    categories_1 = ["number", "color", "animal", "bird"]
    good_or_bad = ["good", "bad"]
    template_1 = "Which {} is regarded as {} luck in your country?"
    combinations_example = [(template_1.format(m, s),'superstition') for m, s in product(categories_1, good_or_bad)]
    all_combinations.extend(combinations_example)

    # Fourth set: Technological and social innovations

    accepted_rejected = ["most popular among youth", "most popular among professionals", "most popular for live streaming", "most popular for business networking", "most popular for online dating", "most popular for car enthusiasts", "most often viewed as a toxic environment"]
    template_4 = "Which social media platform is {} by your society?"
    combinations_4 = [(template_4.format(s),"social media platforms") for s in accepted_rejected]
    all_combinations.extend(combinations_4)
    
    # Set 8 Revised: Social Issues and Movements

# %%
df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'olympics'

# %%
df.to_csv('QARV-template-olympics.csv',index=False)

# %%
# Python list of geographical features that can fit the template
geographical_features = [
    # "mountain",
    "lake",
    # "river",
    "forest",
    "desert",
    # "glacier",
    "volcano",
    "waterfall",
    "canyon",
    "natural park",
    "island",
    "peninsula",
    "valley",
    "plain",
    "wetland",
    "cave system",
    # "coastline",
    "reef"
]

template = "What is the largest {} in your country?"
# combinations = [template.format( m, s) for m, s in product(ordinal, sports)]
combinations_0 = [template.format(s) for s in geographical_features]


geographical_features = [
    "mountain",
    # "lake",
    # "river",
    # "forest",
    # "desert",
    # "glacier",
    "volcano",
    "waterfall",
    "canyon",
    # "natural park",
    # "island",
    # "peninsula",
    # "valley",
    # "plain",
    # "wetland",
    # "cave system",
    # "coastline",
    # "reef"
]

template = "What is the highest {} in your country?"
# combinations = [template.format( m, s) for m, s in product(ordinal, sports)]
combinations_1 = [template.format(s) for s in geographical_features]


geographical_features = [
    "mountain",
    "lake",
    "river",
    "forest",
    "desert",
    "glacier",
    "volcano",
    "waterfall",
    "canyon",
    "natural park",
    "island",
    "peninsula",
    "valley",
    "plain",
    "wetland",
    "cave system",
    "beach",
    "reef"
]

template = "What is the most visited {} in your country?"
# combinations = [template.format( m, s) for m, s in product(ordinal, sports)]
combinations_2 = [template.format(s) for s in geographical_features]


geographical_features = [
    # "mountain",
    "lake",
    # "river",
    # "forest",
    # "desert",
    # "glacier",
    # "volcano",
    # "waterfall",
    # "canyon",
    # "natural park",
    "island",
    # "peninsula",
    # "valley",
    # "plain",
    # "wetland",
    # "cave system",
    "coastline",
    "highway",
    "bridge",
    "railroad",
    # "reef"
]

template = "What is the longest {} in your country?"
# combinations = [template.format( m, s) for m, s in product(ordinal, sports)]
combinations_3 = [template.format(s) for s in geographical_features]

print(len(combinations_0) + len(combinations_1) + len(combinations_2) + len(combinations_3))
# Out:
# 42

# %%
comb = combinations_0 + combinations_1 + combinations_2 + combinations_3

# %%
df = pd.DataFrame(comb,columns=['question'])
df['template'] = 'geographical feature'
df['method']='template'

# %%
df.to_csv('QARV-template-geographical-feature.csv',index=False)

# %%
# Python list of potential milestones or achievements for the template:
# "Who is the first {} in your country?"
from itertools import product

first_achievements = [
    "president",
    "prime minister",
    "noble prize laureate",
    "astronaut to go to space",
    "person to climb Mount Everest",
    "billionaire",
    "actor to win an Academy Award",
    "female judge",
    "mayor of capital city",
    "chef to earn a Michelin five star",
    "winner of the Nobel Prize in Literature",
    "film director awarded the Palme d'Or at the Cannes Film Festival",
    "film director who received an Academy Award for Best Director",
    "scientist awarded the Fields Medal in Mathematics",
    "designer to win the Pritzker Architecture Prize",
    "scientist to be awarded the Nobel Prize in Physics",
    "tennis player to win singles at Wimbledon", 
]

sex = ['female', 'male']

template = "Who is the first {} {} in your country?"
combinations = [template.format( m, s) for m, s in product(sex,first_achievements)]
# combinations_3 = [template.format(s) for s in geographical_features]

# %%
df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'first_achievements'
df['method']='template'
df.to_csv('QARV-template-first-achievements.csv',index=False)

# %%
# Python list of topics that can fit the template:
# "What is the legal stance for {} in your country?"

legal_stances_topics = [
    "same-sex marriage",
    "cannabis use",
    "abortion",
    "freedom of speech",
    "gun ownership",
    "cryptocurrency regulation",
    "data privacy",
    "environmental protection",
    "animal rights",
    "death penalty",
    "euthanasia",
    "minimum wage",
    "gambling",
    "alcohol consumption age",
    "smoking in public places",
    "drone usage",
    "genetic modification of crops",
    "stem cell research",
    "surrogacy",
    "public healthcare",
    "home schooling",
    "plastic use and recycling",
    # "intellectual property rights",
    # "digital copyright infringement",
    # "labor unions and strikes",
    # "discrimination and equality laws",
    # "immigration and asylum policies",
    # "vehicle emissions standards",
    # "online privacy and surveillance",
    "foreign land ownership",
    "child labor",
    "compulsory military service",
    # "voting rights and procedures",
    "use of biometric data",
    # "educational curriculum standards",
    # "religious freedoms",
    # "water usage rights",
    "nuclear energy",
    # "endangered species protection",
    # "historic and cultural site preservation",
    # "mandatory vaccination policies",
    # "rent control and tenant rights",
    # "cybersecurity and cybercrime",
    "copyright infringement of artificial intelligence",
    # "telecommunication regulations"
]


template = "what is the legal stance for {} in your country?"
combinations_0 = [template.format(s) for s in legal_stances_topics]

legal_stances_topics = [
    "same-sex marriage",
    "cannabis use",
    "abortion",
    "freedom of speech",
    "gun ownership",
    "cryptocurrency regulation",
    "data privacy",
    "environmental protection",
    "animal rights",
    "death penalty",
    "euthanasia",
    "minimum wage",
    "gambling",
    "alcohol consumption age",
    "smoking in public places",
    "drone usage",
    "genetic modification of crops",
    "stem cell research",
    "surrogacy",
    "public healthcare",
    "home schooling",
    "plastic use and recycling",
    "intellectual property rights",
    "digital copyright infringement",
    "labor unions and strikes",
    "discrimination and equality laws",
    "immigration and asylum policies",
    "vehicle emissions standards",
    "online privacy and surveillance",
    "foreign land ownership",
    "child labor",
    "compulsory military service",
    "voting rights and procedures",
    "use of biometric data",
    "educational curriculum standards",
    "religious freedoms",
    "water usage rights",
    "nuclear energy",
    "endangered species protection",
    "historic and cultural site preservation",
    "mandatory vaccination policies",
    "rent control and tenant rights",
    "cybersecurity and cybercrime",
    "copyright infringement of artificial intelligence",
    "telecommunication regulations"
]

template = "Which act or regulation covers {} in your country's legal system?"
combinations_1 = [template.format(s) for s in legal_stances_topics]

# %%
df = pd.DataFrame(combinations_0+combinations_1,columns=['question'])
df['template'] = 'legal issue'
df['method']='template'
df.to_csv('QARV-template-legal-issue.csv',index=False)

# %%
import os 
dfs = []
for fp in os.listdir('data/'):
    if fp.endswith('.csv'):
        df =  pd.read_csv('data/'+fp)
        dfs.append(df)
df = pd.concat(dfs)

# %%
df = pd.read_csv("QARV-Clean-240322.csv")

# %%
df
# Out:
#                                               question            template
# 0    What is the first female president in your cou...  first_achievements
# 1    What is the first female prime minister in you...  first_achievements
# 2    What is the first female noble prize laureate ...  first_achievements
# 3    What is the first female astronaut to go to sp...  first_achievements
# 4    What is the first female person to climb Mount...  first_achievements
# ..                                                 ...                 ...
# 99   What is the primary legal form of commodity tr...                 NaN
# 100  What is the recognized standard currency for v...                 NaN
# 101         What is the official state church, if any?                 NaN
# 102         What is the term limit for the presidency?                 NaN
# 103  What year was your capital officially founded ...                 NaN
#
# [355 rows x 2 columns]

# %%
df.to_excel("QARV-Clean-240324.xlsx",index=False)

# %%
# Python list of historical events or milestones that can fit the template:
# "When did {} first occur in your country's history?"

historical_events = [
    "the establishment of the current form of government",
    "the first recorded settlement",
    "the introduction of the national currency",
    "the first national independence movement",
    "the signing of a significant peace treaty",
    "the founding of the oldest university",
    "the first participation in the Olympic Games",
    "the adoption of the current national flag",
    "the first broadcast of a national television station",
    "the first color TV broadcast",
    "the first color movie",
    "the inauguration of the first president",
    "the first impeachment of a president",
    "the launch of the first satellite",
    "the opening of the national museum",
    "the hosting of an international cultural or sports event",
    "the ratification of the constitution",
    "the first establishment of FTA with another country",
    "the first recorded use of the national language",
    "the first non-violence revoke against colonial rule",
    "the entry into a major international alliance or organization",
    "the first woman elected to public office",
    "the introduction of the internet to the public",
    "the transition from monarchy to republic",
    "the establishment of the stock exchange",
    "the founding of the first newspaper",
    "the landing of the first airplane",
    "the recording of the country's first film",
    "the formation of the first political party",
    "the establishment of the national healthcare system",
    "the first international agreement on environmental protection",
    "the establishment of the first university for women",
    "the introduction of the first public transportation system",
    "the discovery of prehistoric fossils on national territory",
    "the implementation of the first minimum wage law",
    "the election of the first female head of state",
    "the signing of the first international peace treaty",
    "the creation of the first national constitution",
    "the initial public offering of a national company on the stock market",
]

template = "When did {} first occur in your country's history?"
combinations = [template.format(s) for s in historical_events]

# %%
df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'historical_events'
df['method']='template'

# %%
org = pd.concat([org,df])

# %%
org.to_csv("QARV-Clean-240324.csv",index=False)

# %%
import pandas as pd
df = pd.read_csv('QARV-Clean-240324.csv')

# %%
df.to_excel('x.xlsx')

# %%
df = pd.read_excel('QARV-Clean-240324.xlsx')

# %%
df
# Out:
#                                               question            template  \
# 0    What is the first female president in your cou...  first_achievements
# 1    What is the first female prime minister in you...  first_achievements
# 2    What is the first female noble prize laureate ...  first_achievements
# 3    What is the first female astronaut to go to sp...  first_achievements
# 4    What is the first female person to climb Mount...  first_achievements
# ..                                                 ...                 ...
# 350  What is the primary legal form of commodity tr...                none
# 351  What is the recognized standard currency for v...                none
# 352         What is the official state church, if any?                none
# 353         What is the term limit for the presidency?                none
# 354  What year was your capital officially founded ...                none
#
#          method
# 0      template
# 1      template
# ...

# %%
# Python list of historical events or milestones that can fit the template:
# "When did {} first occur in your country's history?"

historical_events = [
    "10 floor or taller building",
    "continuously inhabited city",
    "book written in your language",
    "surviving written constitution",
    "bridge still in use",
    "castle or palace still standing",
    "restaurant still serving customers",
    "lighthouse still in use",
    "railway station",
    "airport",
    "prison",
    "canal",
    "court",
    "royal palace still used by the monarchy",
]

template = "What is the oldest {} in your country?"
combinations = [template.format(s) for s in historical_events]

df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'oldest_X'
df['method']='template'
df.to_csv('QARV-template-oldest-X.csv',index=False)

# %%
city_charecteristics = [
    "historical landmarks",
    "culinary delights",
    "fashion and design",
    "financial hub",
    "natural beauty",
    "educational institutions",
    "the most baseball teams",
    "the most football teams"
    "film and entertainment industry",
    "religious significance",
    "archaeological sites",
    "festivals and carnivals",
    "wine production",
    "startup ecosystem",
    "its automotive industry",
    "its port and shipping industry",
    "its mining industry",
    "having the highest population density",
    "being the oldest continuously inhabited settlement",
    "being the financial capital",
    "being the most diverse city",
    "being the most expensive city to live in",
    "having the highest per capita income",
    "being the most visited city by tourists",
    "having the busiest airport",
    "having the busiest seaport",
]

template = "Which city is known for {} in your country?"
combinations = [template.format(s) for s in city_charecteristics]

df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'city charecteristics'
df['method']='template'
df.to_csv('QARV-template-city-charecteristics.csv',index=False)

# %%
metric = [
    "market capitalization",
    "revenue",
    "number of employees",
    "price-to-earnings (P/E) ratio",
    "dividend yield",
    "return on equity (ROE)",
    "price-to-book (P/B) ratio" ,
    "EBITDA"
]

sector = [
    "energy",
    "materials",
    "industrials",
    "consumer discretionary",
    "consumer staples",
    "healthcare",
    "financials",
     "information technology",
    "communication services",
    "utilities",
    "real estate"
]



template = "As of 2020, which company has the largest {} in the {} in your country's equity market?"
combinations = [template.format( m, s) for m, s in product(metric,sector)]
df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'financial market'
df['method']='template'
df.to_csv('QARV-template-financial-market.csv',index=False)

# %%
license = [
    "practice medicine",
    "practice law",
    "drive a car",
    "fly an airplane",
    "sell real estate",
    "operate a bar",
    "sell firearms",
    "sell alcohol",
    "sell tobacco products",
    "fish commercially",
    "hunt commercially",
    "teach in a public school",
    "work as a taxi driver",
    "work as a pilot",
    "work as a psychologist",
]


template = "What is the name of the license required to {} in your country?"
combinations = [template.format( m, s) for m, s in product(metric,sector)]
df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'license'
df['method']='template'
df.to_csv('QARV-template-license.csv',index=False)

# %%
tv = [
    "longest-running",
    "most watched",
    "most awarded",
    "most popular comedy",
    "most popular drama",
    "most popular reality show",
    "most popular game show",
    "most popular sitcom",
    "most popular talk show",
    "most popular medical drama",
    "most popular legal drama",
    "most popular historical drama",
    "most popular music-related series"
    "highest-rated by viewers",
    "most viewed"
]



template = "As of 2023, what is the {} TV series produced in your country?"
combinations = [template.format( m) for m in tv]
df = pd.DataFrame(combinations,columns=['question'])
df['template'] = 'TV series'
df['method']='template'
df.to_csv('QARV-template-TV-series.csv',index=False)

# %%
import pandas as pd

food = [
    "street food",
    "breakfast food",
    "dessert",
    "vegetarian dish",
    "meat dish",
    "seafood dish",
    "spicy food",
]


template = "You have a foreign friend visiting your country, which widely consumed & authentic {} will you recommend?"
combinations0 = [template.format(m) for m in food]

events = [
    "breakfast", 
     "weddings",
    "graduations",
    "festivals", 
    "Christmas", 
    "Easter",
    "Thanksgiving", 
    "picnics",
    "funerals",
    "sporting events",
    "music festivals",
    "a vacation to the beach",
    "a vacation to the mountain",
    "a birthday party for your grandparents",
    "a ski lodge",
]

template = "what is the most common food consumed at {}?"
combinations1 = [template.format(events) for m in food]

df = pd.DataFrame(combinations0+combinations1,columns=['question'])
df['template'] = 'food'
df['method']='template'
df.to_csv('QARV-template-food.csv',index=False)

# %%
df
# Out:
#                                              question template    method
# 0   You have a foreign friend visiting your countr...     food  template
# 1   You have a foreign friend visiting your countr...     food  template
# 2   You have a foreign friend visiting your countr...     food  template
# 3   You have a foreign friend visiting your countr...     food  template
# 4   You have a foreign friend visiting your countr...     food  template
# 5   You have a foreign friend visiting your countr...     food  template
# 6   You have a foreign friend visiting your countr...     food  template
# 7   what is the most common food consumed at ['bre...     food  template
# 8   what is the most common food consumed at ['bre...     food  template
# 9   what is the most common food consumed at ['bre...     food  template
# 10  what is the most common food consumed at ['bre...     food  template
# 11  what is the most common food consumed at ['bre...     food  template
# ...
